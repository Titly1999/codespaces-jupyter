# %%
# !conda install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rainfall = pd.read_csv('E://Datasets//statewise_rainfall.csv')
rainfall
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
rainfall.dropna()
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
rainfall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            641 non-null    float64
#  4   MAR            641 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            641 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %% [markdown]
# 2. Find the district that gets the highest annual rainfall.

# %%
rainfall[['DISTRICT', 'ANNUAL']].max()
# Out:
# DISTRICT    ZUNHEBOTO
# ANNUAL         7229.3
# dtype: object

# %%
# rainfall[rainfall['ANNUAL'] == rainfall['ANNUAL'].max()]['DISTRICT']
rainfall[rainfall['ANNUAL'] == rainfall['ANNUAL'].max()][['DISTRICT', 'ANNUAL']]
# Out:
#       DISTRICT  ANNUAL
# 55  TAMENGLONG  7229.3

# %%
# rainfall[rainfall['ANNUAL'] == rainfall['ANNUAL'].max()]['DISTRICT']
rainfall[rainfall['ANNUAL'] == rainfall['ANNUAL'].min()][['STATE_UT_NAME', 'DISTRICT', 'ANNUAL']]
# Out:
#          STATE_UT_NAME      DISTRICT  ANNUAL
# 353  JAMMU AND KASHMIR  LADAKH (LEH)    94.6

# %%
rainfall.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000
# mean    18.355070   20.984399   30.034789   45.543214   81.535101
# std     21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.900000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.100000   33.900000
# 75%     19.200000   24.100000   33.200000   48.300000   91.900000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   641.000000   641.000000   641.000000  641.000000  641.000000
# mean    196.007332   326.033697   291.152262  194.609048   90.446334
# std     196.556284   221.364643   152.647325   99.830540   74.990685
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %% [markdown]
# 3. Display the top 5 states that get the highest annual rainfall

# %%
rainfall.sort_values('ANNUAL', ascending=False).iloc[0:5, :]
# Out:
#          STATE_UT_NAME       DISTRICT   JAN    FEB    MAR    APR    MAY  \
# 55             MANIPUR     TAMENGLONG  48.5  229.6  224.5  431.5  539.9
# 47           MEGHALAYA  JAINTIA HILLS  33.8   44.1  115.1  282.3  598.8
# 46           MEGHALAYA  EAST KHASI HI  15.4   24.1  129.7  312.5  733.7
# 12   ARUNACHAL PRADESH    UPPER SIANG  74.3  176.7  362.6  397.5  408.7
# 598          KARNATAKA          UDUPI   1.4    0.4    4.1   29.4  193.8
#
#         JUN     JUL     AUG    SEP    OCT    NOV   DEC  ANNUAL  Jan-Feb  \
# 55   1158.7  1820.9  1522.1  726.3  376.1  144.0   7.2  7229.3    278.1
# 47   1316.1  1591.3   933.8  826.3  517.7  110.9   9.7  6379.9     77.9
# 46   1476.2  1518.4  1019.4  607.8  277.9   40.3  10.7  6166.1     39.5
# 12    801.9   653.0   417.9  686.0  264.9   86.9  71.7  4402.1    251.0
# 598  1081.0  1371.6   902.2  404.9  223.8   74.6  18.8  4306.0      1.8
#
#      Mar-May  Jun-Sep  Oct-Dec
# 55    1195.9   5228.0    527.3
# 47     996.2   4667.5    638.3
# ...

# %%
rainfall_sorted = rainfall.sort_values('ANNUAL', ascending=False)
rainfall_sorted.drop_duplicates('STATE_UT_NAME').iloc[0:5, 0]
# Out:
# 55               MANIPUR
# 47             MEGHALAYA
# 12     ARUNACHAL PRADESH
# 598            KARNATAKA
# 32                 ASSAM
# Name: STATE_UT_NAME, dtype: object

# %%
rainfall_sorted['STATE_UT_NAME'].unique()[0:5]
# Out:
# array(['MANIPUR', 'MEGHALAYA', 'ARUNACHAL PRADESH', 'KARNATAKA', 'ASSAM'],
#       dtype=object)

# %% [markdown]
# Drop the columns 'Jan-Feb', 'Mar-May', 'Jun-Sep' and 'Oct-Dec'.

# %%
rainfall.drop(columns=['Jan-Feb', 'Mar-May', 'Jun-Sep''Oct-Dec'], inplace=True
# Out:
#                    STATE_UT_NAME    JAN   FEB    MAR    APR    MAY    JUN  \
# 0    ANDAMAN And NICOBAR ISLANDS  107.3  57.9   65.2  117.0  358.5  295.5
# 1    ANDAMAN And NICOBAR ISLANDS   43.7  26.0   18.6   90.5  374.4  457.2
# 2    ANDAMAN And NICOBAR ISLANDS   32.7  15.9    8.6   53.4  343.6  503.3
# 3              ARUNACHAL PRADESH   42.2  80.8  176.4  358.5  306.4  447.0
# 4              ARUNACHAL PRADESH   33.3  79.5  105.9  216.5  323.0  738.3
# ..                           ...    ...   ...    ...    ...    ...    ...
# 636                       KERALA   13.4  22.1   43.6  150.4  232.6  651.6
# 637                       KERALA    2.3   1.0    8.4   46.9  217.6  999.6
# 638                       KERALA   19.8  45.2   73.9  184.9  294.7  556.9
# 639                       KERALA    4.8   8.3   17.5   83.3  174.6  698.1
# 640                  LAKSHADWEEP   20.8  14.7   11.8   48.9  171.7  330.2
#
#         JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL
# ...

# %%
rainfall
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
districts = rainfall.groupby('STATE_UT_NAME').count()['DISTRICT']

# %%
# set the figure size
plt.rcParams['figure.figsize'] = (10, 8)

# %%
districts.plot(kind="barh")

# adjusting the figure size
# fig = plt.figure(figsize=(6.4, 4.8))

plt.xlabel('DISTRICTS')
plt.ylabel('STATES')

plt.show()

# %% [markdown]
# For each state, display the district that gets the highest rainfall in May. Also display the recorded rainfall.

# %%
rainfall['MAY'].describe()
# Out:
# count    641.000000
# mean      81.535101
# std      111.960390
# min        0.900000
# 25%       12.100000
# 50%       33.900000
# 75%       91.900000
# max      733.700000
# Name: MAY, dtype: float64

# %%
rainfall.groupby('STATE_UT_NAME')[['DISTRICT', 'MAY']].min()
# Out:
#                                    DISTRICT    MAY
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN  343.6
# ANDHRA PRADESH                     ADILABAD   18.2
# ARUNACHAL PRADESH             ANJAW (LOHIT)  140.5
# ASSAM                         BAKSA BARPETA  139.4
# BIHAR                                ARARIA   11.2
# CHANDIGARH                       CHANDIGARH   30.1
# CHATISGARH                           BASTAR    5.8
# DADAR NAGAR HAVELI                      DNH    7.4
# DAMAN AND DUI                         DAMAN    0.9
# DELHI                         CENTRAL DELHI   19.3
# GOA                               NORTH GOA   81.2
# GUJARAT                           AHMEDABAD    1.2
# HARYANA                              AMBALA    7.7
# HIMACHAL                           BILASPUR   26.8
# JAMMU AND KASHMIR                  ANANTNAG    8.0
# JHARKHAND                            BOKARO   10.5
# KARNATAKA                         BAGALKOTE   31.4
# ...

# %%
from urllib.request import urlretrieve

urlretrieve('https://gist.githubusercontent.com/raun1997/51e3526247747512b45d876d510afa54/raw/af93420bb0b60ebe5ed11f2fbb07788887182a55/autompg.csv', 'E://Datasets//autompg.csv')
# Out:
# ('E://Datasets//autompg.csv', <http.client.HTTPMessage at 0x2811d6f1d00>)

# %%
autompg = pd.read_csv('autompg.csv')
autompg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# Retrieve details of all the cars built in year 72.

# %%
autompg[autompg['model_year']==72].head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 57  24.0          4         113.0        95.0    2278          15.5
# 58  25.0          4          97.5        80.0    2126          17.0
# 59  23.0          4          97.0        54.0    2254          23.5
# 60  20.0          4         140.0        90.0    2408          19.5
# 61  21.0          4         122.0        86.0    2226          16.5
#
#     model_year  origin                   name
# 57          72   japan  toyota corona hardtop
# 58          72     usa     dodge colt hardtop
# 59          72  europe      volkswagen type 3
# 60          72     usa         chevrolet vega
# 61          72     usa    ford pinto runabout

# %%
japan = autompg[(autompg['origin']=='japan') & (autompg['cylinders']==6)]
japan
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 123  20.0          6         156.0       122.0    2807          13.5
# 210  19.0          6         156.0       108.0    2930          15.5
# 241  22.0          6         146.0        97.0    2815          14.5
# 333  32.7          6         168.0       132.0    2910          11.4
# 361  25.4          6         168.0       116.0    2900          12.6
# 362  24.2          6         146.0       120.0    2930          13.8
#
#      model_year origin               name
# 123          73  japan     toyota mark ii
# 210          76  japan     toyota mark ii
# 241          77  japan         datsun 810
# 333          80  japan      datsun 280-zx
# 361          81  japan    toyota cressida
# 362          81  japan  datsun 810 maxima

# %% [markdown]
# - ## Pie Chart Visualization: Create a pie chart presenting the origin proportions

# %%
group_count = autompg['origin'].value_counts()

# %%
plt.rcParams['figure.figsize'] = (10, 4)

# %%
plt.style.use('dark_background')

# %%
group_count.plot(kind="pie",
                 legend=True,
                 colors=['orange', 'green', 'yellow'],
                 explode=(0.10, 0.11, 0.11))

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6560\2523725272.py in <module>
# ----> 1 group_count.plot(kind="pie",
#       2                  legend=True,
#       3                  colors=['orange', 'green', 'yellow'],
#       4                  explode=(0.10, 0.11, 0.11))
#       5
#
# NameError: name 'group_count' is not defined

# %% [markdown]
# ## Line Chart: Italy Covid Analysis

# %%
covid_italy = pd.read_csv('E://Datasets//italy-covid-daywise.csv',
                         index_col='date')
covid_italy
# Out:
#             new_cases  new_deaths  new_tests
# date
# 2019-12-31        0.0         0.0        NaN
# 2020-01-01        0.0         0.0        NaN
# 2020-01-02        0.0         0.0        NaN
# 2020-01-03        0.0         0.0        NaN
# 2020-01-04        0.0         0.0        NaN
# ...               ...         ...        ...
# 2020-08-30     1444.0         1.0    53541.0
# 2020-08-31     1365.0         4.0    42583.0
# 2020-09-01      996.0         6.0    54395.0
# 2020-09-02      975.0         8.0        NaN
# 2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 3 columns]

# %%
# plt.style.use('classic')
covid_italy['new_deaths'].plot(legend=True)

plt.xlabel('DATES')
plt.ylabel('DEATHS')
# Out:
# Text(0, 0.5, 'DEATHS')

# %%
plt.text??
# Out:
# Signature: plt.text(x, y, s, fontdict=None, **kwargs)
# Docstring:
# Add text to the Axes.
#
# Add the text *s* to the Axes at location *x*, *y* in data coordinates.
#
# Parameters
# ----------
# x, y : float
#     The position to place the text. By default, this is in data
#     coordinates. The coordinate system can be changed using the
#     *transform* parameter.
#
# s : str
#     The text.
#
# fontdict : dict, default: None
#     A dictionary to override the default text properties. If fontdict
#     is None, the defaults are determined by `.rcParams`.
#
# Returns
# -------
# `.Text`
#     The created `.Text` instance.
#
# Other Parameters
# ----------------
# **kwargs : `~matplotlib.text.Text` properties.
#     Other miscellaneous text parameters.
#
#     Properties:
#     agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#     alpha: scalar or None
# ...

# %%
plt.style.use('ggplot')

covid_italy['new_deaths'].plot(legend=True)

plt.xlabel('DATES')
plt.ylabel('DEATHS')
# Out:
# Text(0, 0.5, 'DEATHS')
