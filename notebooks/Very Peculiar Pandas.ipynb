# %%
# for data preprocessing, csv file I/O etc.
import pandas as pd

# data visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# set seaborn style to white
sns.set_style('white')

# magic command to render graphs in this notebook
# %matplotlib inline

# for linear algebra
import numpy as np

# %% [markdown]
# # Infytq

# %% [markdown]
# - ## Import the data into Python environment as a Pandas DataFrame.

# %%
rainfall = pd.read_csv('E://Datasets//statewise_rainfall.csv')
autompg = pd.read_csv('E://Datasets//autompg.csv')

# %%
rainfall.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000
# mean    18.355070   20.984399   30.034789   45.543214   81.535101
# std     21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.900000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.100000   33.900000
# 75%     19.200000   24.100000   33.200000   48.300000   91.900000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   641.000000   641.000000   641.000000  641.000000  641.000000
# mean    196.007332   326.033697   291.152262  194.609048   90.446334
# std     196.556284   221.364643   152.647325   99.830540   74.990685
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %%
rainfall
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
autompg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# - ## Retrieve details of all the cars built in year 72.

# %%
autompg.loc[autompg.model_year==72].head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 57  24.0          4         113.0        95.0    2278          15.5
# 58  25.0          4          97.5        80.0    2126          17.0
# 59  23.0          4          97.0        54.0    2254          23.5
# 60  20.0          4         140.0        90.0    2408          19.5
# 61  21.0          4         122.0        86.0    2226          16.5
#
#     model_year  origin                   name
# 57          72   japan  toyota corona hardtop
# 58          72     usa     dodge colt hardtop
# 59          72  europe      volkswagen type 3
# 60          72     usa         chevrolet vega
# 61          72     usa    ford pinto runabout

# %% [markdown]
# - ## Retrieve details of all the cars built in Japan having 6 cylinders.

# %%
autompg.loc[(autompg.origin=='japan') & (autompg.cylinders==6)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 123  20.0          6         156.0       122.0    2807          13.5
# 210  19.0          6         156.0       108.0    2930          15.5
# 241  22.0          6         146.0        97.0    2815          14.5
# 333  32.7          6         168.0       132.0    2910          11.4
# 361  25.4          6         168.0       116.0    2900          12.6
# 362  24.2          6         146.0       120.0    2930          13.8
#
#      model_year origin               name
# 123          73  japan     toyota mark ii
# 210          76  japan     toyota mark ii
# 241          77  japan         datsun 810
# 333          80  japan      datsun 280-zx
# 361          81  japan    toyota cressida
# 362          81  japan  datsun 810 maxima

# %% [markdown]
# - ## Pie Chart Visualization: Create a pie chart presenting the origin proportions

# %%
# set the figure size
plt.rcParams['figure.figsize'] = (4, 4)

# choose ggplot's style
plt.style.use('ggplot')

# %%
autompg.origin.value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
autompg.origin.value_counts().plot(kind="pie",
                                   colors=['#2ecc71', '#1abc9c', '#16a085'],
                                   startangle = 90,
                                   autopct="%.2f",
                                   legend=True)
plt.tight_layout()                                         
plt.show()

# %% [markdown]
# * ## Check for missing values in rainfall dataset, if any and drop the corresponding rows.

# %%
rainfall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            641 non-null    float64
#  4   MAR            641 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            641 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %% [markdown]
# As you can follow, no missing values have been found.

# %% [markdown]
# - ## Find the district that gets the highest annual rainfall.

# %%
rainfall['DISTRICT'][rainfall.ANNUAL == rainfall['ANNUAL'].max()]
# Out:
# 55    TAMENGLONG
# Name: DISTRICT, dtype: object

# %% [markdown]
# However, the following displays both the district that gets the highest annual rainfall and the rainfall it receives.

# %%
rainfall[['DISTRICT', 'ANNUAL']][rainfall.ANNUAL == rainfall['ANNUAL'].max()]
# Out:
#       DISTRICT  ANNUAL
# 55  TAMENGLONG  7229.3

# %% [markdown]
# - ## Line Chart Visualization

# %%
rainfall.replace({'STATE_UT_NAME':{ 
    'ANDAMAN And NICOBAR ISLANDS': 'AN'
}}, inplace=True)

# %%
rainfall_indexed = rainfall.set_index('STATE_UT_NAME')
rainfall_indexed
# Out:
#                          DISTRICT    JAN   FEB    MAR    APR    MAY    JUN  \
# STATE_UT_NAME
# AN                        NICOBAR  107.3  57.9   65.2  117.0  358.5  295.5
# AN                  SOUTH ANDAMAN   43.7  26.0   18.6   90.5  374.4  457.2
# AN                  N & M ANDAMAN   32.7  15.9    8.6   53.4  343.6  503.3
# ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5  306.4  447.0
# ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5  323.0  738.3
# ...                           ...    ...   ...    ...    ...    ...    ...
# KERALA                     IDUKKI   13.4  22.1   43.6  150.4  232.6  651.6
# KERALA                   KASARGOD    2.3   1.0    8.4   46.9  217.6  999.6
# KERALA             PATHANAMTHITTA   19.8  45.2   73.9  184.9  294.7  556.9
# KERALA                    WAYANAD    4.8   8.3   17.5   83.3  174.6  698.1
# LAKSHADWEEP           LAKSHADWEEP   20.8  14.7   11.8   48.9  171.7  330.2
#
# ...

# %%
# set the figure size
plt.rcParams['figure.figsize'] = (10, 8)

# %%
rainfall_indexed['ANNUAL'].plot(ylabel='rainfall',
                       xlabel='index')

# tight layout
plt.tight_layout()

# display the plot
plt.show()

# %% [markdown]
# - ## Display the top 5 states that get the highest annual rainfall.

# %%
rainfall_sorted = rainfall.sort_values(by='ANNUAL', ascending=False)
top_five_uniquestates = pd.Series(rainfall_sorted.STATE_UT_NAME.unique()[:5])

top_five_uniquestates
# Out:
# 0              MANIPUR
# 1            MEGHALAYA
# 2    ARUNACHAL PRADESH
# 3            KARNATAKA
# 4                ASSAM
# dtype: object

# %%
type(top_five_uniquestates)
# Out:
# pandas.core.series.Series

# %%
rainfall_sorted.drop_duplicates(subset=['STATE_UT_NAME'])['STATE_UT_NAME'].head()
# Out:
# 55               MANIPUR
# 47             MEGHALAYA
# 12     ARUNACHAL PRADESH
# 598            KARNATAKA
# 32                 ASSAM
# Name: STATE_UT_NAME, dtype: object

# %%
plt.style.use('fivethirtyeight')

# %%
rainfall_sorted = rainfall.sort_values(by='ANNUAL', ascending=False)
unique_topfive = rainfall_sorted.drop_duplicates(subset=['STATE_UT_NAME'])[["STATE_UT_NAME", "ANNUAL"]].head()

# plt.xticks()

unique_topfive.plot(kind="barh")
plt.show()

# %% [markdown]
# - ## Drop the columns 'Jan-Feb', 'Mar-May', 'Jun-Sep' and 'Oct-Dec'.

# %%
rainfall.drop(columns=['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'], inplace=True)
rainfall
# Out:
#          STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR    MAY  \
# 0                   AN         NICOBAR  107.3  57.9   65.2  117.0  358.5
# 1                   AN   SOUTH ANDAMAN   43.7  26.0   18.6   90.5  374.4
# 2                   AN   N & M ANDAMAN   32.7  15.9    8.6   53.4  343.6
# 3    ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5  306.4
# 4    ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5  323.0
# ..                 ...             ...    ...   ...    ...    ...    ...
# 636             KERALA          IDUKKI   13.4  22.1   43.6  150.4  232.6
# 637             KERALA        KASARGOD    2.3   1.0    8.4   46.9  217.6
# 638             KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9  294.7
# 639             KERALA         WAYANAD    4.8   8.3   17.5   83.3  174.6
# 640        LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9  171.7
#
#        JUN     JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL
# ...

# %% [markdown]
# - ## Display the state-wise mean rainfall for all months using a pivot table.

# %%
# rainfall.loc[:, 'JAN':'DEC'].mean()
rainfall.groupby(by='STATE_UT_NAME').mean()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13580\557110612.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rainfall.groupby(by='STATE_UT_NAME').mean()
#                           JAN        FEB         MAR         APR         MAY  \
# STATE_UT_NAME
# AN                  61.233333  33.266667   30.800000   86.966667  358.833333
# ANDHRA PRADESH       6.321739   7.352174   10.095652   19.873913   48.765217
# ARUNACHAL PRADESH   53.687500  93.293750  165.018750  275.162500  300.262500
# ASSAM               15.733333  31.714815   77.762963  181.266667  333.870370
# BIHAR               13.134211   9.278947    9.873684   16.865789   51.673684
# CHANDIGARH          44.300000  38.900000   33.200000   14.800000   30.100000
# ...

# %%
rainfall.pivot_table(columns='STATE_UT_NAME')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13580\1656307417.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   rainfall.pivot_table(columns='STATE_UT_NAME')
# STATE_UT_NAME           AN  ANDHRA PRADESH  ARUNACHAL PRADESH        ASSAM  \
# ANNUAL         2911.400000      945.073913         2927.37500  2454.359259
# APR              86.966667       19.873913          275.16250   181.266667
# AUG             385.300000      179.426087          378.60000   377.370370
# DEC             159.733333       15.565217           35.95625    11.440741
# FEB              33.266667        7.352174           93.29375    31.714815
# JAN              61.233333        6.321739           53.68750    15.733333
# JUL             390.566667      185.365217          547.58125   494.844444
# ...

# %% [markdown]
# - ## Display count of districts in each state.

# %%
groupstates = rainfall.groupby(by='STATE_UT_NAME')
districts = groupstates['DISTRICT'].count()
districts
# Out:
# STATE_UT_NAME
# AN                     3
# ANDHRA PRADESH        23
# ARUNACHAL PRADESH     16
# ASSAM                 27
# BIHAR                 38
# CHANDIGARH             1
# CHATISGARH            18
# DADAR NAGAR HAVELI     1
# DAMAN AND DUI          2
# DELHI                  9
# GOA                    2
# GUJARAT               26
# HARYANA               21
# HIMACHAL              12
# JAMMU AND KASHMIR     22
# JHARKHAND             24
# KARNATAKA             30
# KERALA                14
# LAKSHADWEEP            1
# MADHYA PRADESH        50
# MAHARASHTRA           35
# MANIPUR                9
# MEGHALAYA              7
# MIZORAM                9
# NAGALAND              11
# ORISSA                30
# PONDICHERRY            4
# PUNJAB                20
# RAJASTHAN             33
# SIKKIM                 4
# TAMIL NADU            32
# TRIPURA                4
# UTTAR PRADESH         71
# UTTARANCHAL           13
# WEST BENGAL           19
# Name: DISTRICT, dtype: int64

# %%
districtsnum = rainfall['STATE_UT_NAME'].value_counts()
districtsnum
# Out:
# UTTAR PRADESH         71
# MADHYA PRADESH        50
# BIHAR                 38
# MAHARASHTRA           35
# RAJASTHAN             33
# TAMIL NADU            32
# KARNATAKA             30
# ORISSA                30
# ASSAM                 27
# GUJARAT               26
# JHARKHAND             24
# ANDHRA PRADESH        23
# JAMMU AND KASHMIR     22
# HARYANA               21
# PUNJAB                20
# WEST BENGAL           19
# CHATISGARH            18
# ARUNACHAL PRADESH     16
# KERALA                14
# UTTARANCHAL           13
# HIMACHAL              12
# NAGALAND              11
# MIZORAM                9
# MANIPUR                9
# DELHI                  9
# MEGHALAYA              7
# SIKKIM                 4
# TRIPURA                4
# PONDICHERRY            4
# AN                     3
# GOA                    2
# DAMAN AND DUI          2
# DADAR NAGAR HAVELI     1
# CHANDIGARH             1
# LAKSHADWEEP            1
# Name: STATE_UT_NAME, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (10, 10)
plt.style.use('fivethirtyeight')

# %%
# plotting a horizontal bar graph
districtsnum.plot(kind="barh")

# setting the labels
plt.ylabel('STATES')
plt.xlabel('DISTRICT COUNT')

plt.tight_layout()
plt.show()

# %%
plt.rcParams??
# Out:
# Type:        RcParams
# String form:
# _internal.classic_mode: False
# agg.path.chunksize: 0
# animation.bitrate: -1
# animation.codec: h264
# animation.convert_args: ['-layers', 'OptimizePlus']
# animation.convert_path: convert
# animation.embed_limit: 20.0
# animation.ffmpeg_args: []
# animation.ffmpeg_path: ffmpeg
# animation.frame_format: png
# animation.html: none
# animation.writer: ffmpeg
# axes.autolimit_mode: data
# axes.axisbelow: True
# axes.edgecolor: #f0f0f0
# axes.facecolor: #f0f0f0
# axes.formatter.limits: [-5, 6]
# axes.formatter.min_exponent: 0
# axes.formatter.offset_threshold: 4
# axes.formatter.use_locale: False
# axes.formatter.use_mathtext: False
# axes.formatter.useoffset: True
# axes.grid: True
# axes.grid.axis: both
# axes.grid.which: major
# axes.labelcolor: #555555
# axes.labelpad: 4.0
# axes.labelsize: large
# axes.labelweight: normal
# axes.linewidth: 3.0
# ...

# %%
plt.plot??

# %% [markdown]
# - ## For each state, display the district that gets the highest rainfall in May. Also display the recorded rainfall.

# %%
mayhighestrainfall = groupstates[['DISTRICT', 'MAY']].max()
mayhighestrainfall
# rainfall.groupby(by='STATE_UT_NAME')[['DISTRICT']]
# Out:
#                           DISTRICT    MAY
# STATE_UT_NAME
# AN                   SOUTH ANDAMAN  374.4
# ANDHRA PRADESH       WEST GODAVARI   96.6
# ARUNACHAL PRADESH       WEST SIANG  453.0
# ASSAM                UDALGURI(DARA  604.0
# BIHAR               WEST CHAMPARAN  155.7
# CHANDIGARH              CHANDIGARH   30.1
# CHATISGARH                 SURGUJA   38.6
# DADAR NAGAR HAVELI             DNH    7.4
# DAMAN AND DUI                  DIU    7.4
# DELHI                   WEST DELHI   19.3
# GOA                      SOUTH GOA   94.3
# GUJARAT                     VALSAD   12.5
# HARYANA                YAMUNANAGAR   27.9
# HIMACHAL                       UNA   91.7
# JAMMU AND KASHMIR         UDHAMPUR  111.4
# JHARKHAND           WEST SINGHBHUM   86.1
# KARNATAKA                   YADGIR  193.8
# KERALA                     WAYANAD  300.4
# LAKSHADWEEP            LAKSHADWEEP  171.7
# MADHYA PRADESH             VIDISHA   19.9
# MAHARASHTRA               YAVATMAL   60.2
# ...

# %%
groupstates.get_group('KERALA').max()
# Out:
# STATE_UT_NAME     KERALA
# DISTRICT         WAYANAD
# JAN                 19.8
# FEB                 45.2
# MAR                 73.9
# APR                184.9
# MAY                300.4
# JUN                999.6
# JUL               1110.4
# AUG                636.3
# SEP                308.4
# OCT                362.7
# NOV                221.4
# DEC                 62.7
# ANNUAL            3621.6
# dtype: object

# %%
plt.style.use('fivethirtyeight')

# creating the bar plot
mayhighestrainfall.plot(kind="barh")

# setting the xlabel
plt.xlabel("States")
# setting the ylabel
plt.ylabel('Rainfall') 

# displaying the plot
plt.show()

# %%
plt.style.use('ggplot')

# creating the bar plot
mayhighestrainfall.plot(kind="barh")

# setting the xlabel
plt.xlabel("States")
# setting the ylabel
plt.ylabel('Rainfall') 

# displaying the plot
plt.show()

# %%
rainfall.MAY.describe()
# Out:
# <pre>count    641.000000
# mean      81.535101
# std      111.960390
# min        0.900000
# 25%       12.100000
# 50%       33.900000
# 75%       91.900000
# max      733.700000
# Name: MAY, dtype: float64</pre>

# %% [markdown]
# # PyNative

# %%
automobile = pd.read_csv('E://Datasets//Automobile_Data.csv')
automobile
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
automobile.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   61.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %% [markdown]
# - ## From the given dataset, print the first and the last rows.

# %%
automobile.iloc[:5, :]
# automobile.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
automobile.iloc[-5:]
# automobile.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# - ## Clean the dataset and update the CSV file. Replace all column values which contain `?`, `n.a.` or `NaN`.

# %%
automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 5.2+ KB

# %%
automobile_cleaned = pd.read_csv('E://Datasets//Automobile_Data.csv', na_values={
    'price': ['?', 'n.a'],
    'stroke': ['?', 'n.a'],
    'horsepower': ['?', 'n.a'],
    'peak-rpm': ['?', 'n.a'],
    'average-mileage': ['?', 'n.a']
})

# print(automobile_cleaned)

automobile_cleaned.to_csv('Automobile.csv')

# %%
automobile = pd.read_csv('Automobile.csv',index_col=0)
automobile
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
automobile.fillna??

# %% [markdown]
# - ## Find the most expensive car company name.

# %%
automobile.price.describe()
# Out:
# count       58.000000
# mean     15387.000000
# std      11320.259841
# min       5151.000000
# 25%       6808.500000
# 50%      11095.000000
# 75%      18120.500000
# max      45400.000000
# Name: price, dtype: float64

# %%
# automobile.loc[:, ['company', 'price']][automobile.price == automobile.price.max()]
automobile[['company', 'price']][automobile.price == automobile.price.max()]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# - ## Print all Toyota cars details.

# %%
automobile.loc[automobile.company == 'toyota']
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %%
company_name = automobile.groupby(by='company')
toyota_cars = company_name.get_group('toyota')
toyota_cars
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %% [markdown]
# - ## Count total cars per company.

# %%
# automobile.value_counts(subset=['company'])
automobile['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
automobile['company'].value_counts().plot(kind="barh")

# %% [markdown]
# - ## Find each company's highest price car.

# %%
automobile.groupby(by='company')[['company', 'price']].apply(lambda x: x.max())
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
car_manufacturers = automobile.groupby(by='company')
pricedf = car_manufacturers[['company', 'price']].max()
pricedf
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
len(pricedf)
# Out:
# 16

# %%
pricedf.plot(kind="barh", ylabel='price')

plt.text(1, 1, '$Hi$')

plt.show()

# %% [markdown]
# - ## Find the average mileage of each car making company.

# %%
avg_mileage = car_manufacturers['average-mileage'].mean()
avg_mileage
# Out:
# <pre>company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64</pre>

# %% [markdown]
# - ## Sort all cars by `price` column.

# %%
sorted_by_price = automobile.sort_values(by=['price'], ascending=False)
sorted_by_price.iloc[:5]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>company</th>
#       <th>body-style</th>
#       <th>wheel-base</th>
#       <th>length</th>
#       <th>engine-type</th>
#       <th>num-of-cylinders</th>
#       <th>horsepower</th>
#       <th>average-mileage</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>47</td>
#       <td>mercedes-benz</td>
#       <td>hardtop</td>
#       <td>112.0</td>
#       <td>199.2</td>
#       <td>ohcv</td>
#       <td>eight</td>
#       <td>184</td>
#       <td>14</td>
#       <td>45400.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
# ...

# %% [markdown]
# - ## Concatenate two data frames using the following conditions.

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
germancarsdf = pd.DataFrame(GermanCars)
japcarsdf = pd.DataFrame(japaneseCars)

# %%
pd.concat([germancarsdf, japcarsdf], keys=['Germany', 'Japan'])
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %% [markdown]
# - ## Merge two data frames using the following condition:
#     Create two data frames using the following two Dicts, Merge two data frames, and append the second data frame as a new column to the first data frame.

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
car_prices = pd.DataFrame(Car_Price)
car_hp = pd.DataFrame(car_Horsepower)

# %%
car_prices
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
car_hp
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
pd.merge(left=car_prices, right=car_hp)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Company</th>
#       <th>Price</th>
#       <th>horsepower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Toyota</td>
#       <td>23845</td>
#       <td>141</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Honda</td>
#       <td>17995</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BMV</td>
#       <td>135925</td>
#       <td>182</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Audi</td>
#       <td>71400</td>
#       <td>160</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Jovian

# %% [markdown]
# ## Line Plot

# %%
covid_italy = pd.read_csv('E://Datasets//italy-covid-daywise.csv',
                          index_col='date')
covid_italy
# Out:
#             new_cases  new_deaths  new_tests
# date
# 2019-12-31        0.0         0.0        NaN
# 2020-01-01        0.0         0.0        NaN
# 2020-01-02        0.0         0.0        NaN
# 2020-01-03        0.0         0.0        NaN
# 2020-01-04        0.0         0.0        NaN
# ...               ...         ...        ...
# 2020-08-30     1444.0         1.0    53541.0
# 2020-08-31     1365.0         4.0    42583.0
# 2020-09-01      996.0         6.0    54395.0
# 2020-09-02      975.0         8.0        NaN
# 2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 3 columns]

# %%
covid_italy.new_deaths.plot()

plt.ylabel('Deaths')
plt.xlabel('Dates')
# Out:
# Text(0.5, 0, 'Dates')

# %%
covid_italy.new_cases.plot()
# Out:
# <AxesSubplot: xlabel='date'>
